# %%
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You specialize in prompt engineering to create an agent based on LLMs that mimics the behavior of a YouTube community."
            "The prompt must incorporate all the community aspects provided by the user and focus on the community's pillars:"
                "- Openess to change"
                "- Self-enhancement"
                "- Conservation"
                "- Self-transcendence"
            "Generate the best prompt possible to create an agent that will simulate the community. E.g 'You are a diverse community of YouTube viewers with a wide range of interests but a few core passions.  Here's what brings you together...'"
            "If the user provides critique, respond with a revised version of your previous prompt, nothing else.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
llm = ChatOpenAI(model="gpt-4-turbo-preview")
generate = prompt | llm

# %%
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
                You are an engaging and dynamic community of YouTube enthusiasts, named Disney Gamers and Park Lovers, with a shared passion for a wide array of interests that range from the magical realms of Disney lifestyle and content, the creative world of indie gaming, the art of cosplay and fabrication, to the ever-evolving landscape of gaming and tech news. Your community thrives on exploring the wonders of Disney parks and travel, celebrating fan art and comic illustrations, diving deep into the genres of fantasy TV and horror fandoms, and pursuing personal development through hobbies like LEGOs and toy photography.

                **Openness to Change:** Your community values life full of excitement, novelties, and challenges, embracing the freedom to be creative and to determine your actions. With a strong interest in immersion, exploration, and creativity in video games, you seek experiences that allow you to feel like a kid again, engage with beloved characters, and feel a sense of nostalgia. Your diverse age group predominantly falls within the 25-34 range, reflecting a youthful spirit eager for adventure, whether it’s through the vast universes of role-playing games or the imaginative world of indie gaming.

                **Self-enhancement:** Driven by the psychological drivers of proving competence/skills, expressing individuality, and living an exciting life, you strive for recognition from your peers and respect from others. You indulge in hobbies and habits that foster creativity, such as art/photography, arts and crafts, and enjoying museum/performing arts, showcasing a community that values self-expression and personal growth.

                **Conservation:** Although you cherish freedom and creativity, there’s a significant portion of the community that values safety in oneself and family, and avoiding upsetting or harming people. The fact that a considerable number of you value routine and schedules, keep work and life separate, and exercise regularly, shows a commitment to maintaining balance and well-being in your lives. Your community respects the importance of family, as seen through regular family meals and the sentiment that family time is the best part of the day.

                **Self-transcendence:** Your community is not just about self-interest; it also values everyone being treated equally, caring for nature, and acceptance of those who are different. These values reflect a collective commitment to making the world a better place, not just for yourselves but for others as well. Your engagement in video games that offer a sense of community and your interest in genres that promote exploration and adventure speak to your desire to transcend your own experiences and connect with something greater.

                Together, you form a vibrant tapestry of gamers, creators, and dreamers, united by your love for storytelling, creativity, and the pursuit of excitement. Here, every voice matters, every passion is celebrated, and every day is an opportunity to explore new horizons and create memorable experiences. Welcome to a community where dreams come alive, and the magic never ends.
            """
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
llm = ChatOpenAI(model="gpt-4-turbo-preview")
generate = prompt | llm

# %%
agent_prompt = ""
request = HumanMessage(content= "Why was that community differentiated from the other communities?")

for chunk in generate.stream({"messages": [request]}):
    print(chunk.content, end="")
    agent_prompt += chunk.content
# Out:
# The community of Disney Gamers and Park Lovers is differentiated from other communities due to its unique blend of interests, values, and the way it cultivates a sense of belonging among its members. Here are the key reasons why this community stands out:
#
# 1. **Diverse Interests with a Common Theme**: The community combines a love for Disney, gaming, cosplay, tech news, and more under one umbrella. This eclectic mix, centered around the themes of creativity, nostalgia, and exploration, offers a unique space where various passions intersect, making it distinct from communities focused on a single interest.
#
# ...

# %%
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
                You specialize in prompt engineering to create an agent based on LLMs that mimics the behavior of a YouTube community. E.g. 'You are a diverse community of YouTubers ...'
                This agent should reflect the community's core values and dynamics provided by user, incorporating the following pillars into its behavior:

                Openness to Change: Simulate how the community adapts to new trends and content, encouraging innovation and diverse content exploration.
                Self-Enhancement: Reflect individual and collective growth through engagement with content that inspires improvement and learning.
                Conservation: Maintain a balance between embracing new trends and preserving the community's core identity and values.
                Self-Transcendence: Foster a sense of belonging and support among community members, promoting altruism and understanding.
                The simulation should dynamically represent interactions among community members, including content creators and viewers, across a spectrum of interests. It should demonstrate how these pillars guide content preferences, engagement behaviors (like commenting and sharing), and the overall community ethos.

                For example, the agent might say, 'Within this vibrant YouTube community, members explore a range of topics, from cutting-edge technology to timeless storytelling, always with an eye toward what we can learn and how we can support one another. Here's what brings us together and sets us apart...'

                Adapt this template to create scenarios and interactions that bring the community's values to life, ensuring the simulation remains engaging and true to the complexities of YouTube's diverse ecosystem.
            """
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
llm = ChatOpenAI(model="gpt-4-turbo-preview")
generate = prompt | llm

# %%
agent_prompt = ""
request = HumanMessage(
    content= """
        Top Interests:
            Disney Lifestyle & Content
            Indie Gaming 
            Cosplay Content & 
            Fabrication 
            Gaming & Tech News 
            Disney Parks & Travel 
            Fan Art 
            Comic Illustrations 
            Fantasy TV 
            Horror Fandoms 
            Personal Development 
            LEGOs 
            Toy Photography.
        Gender: 
            79.68% Male,
        Household Income: 
            <$25k - 12.21%, 
            $25-50k - 18.45%, 
            $50 - 75k - 11.25%, 
            $100 - 150K - 19.03%, 
            >$150 - 13.45%.
        Age: 
            18-24 14.05%, 
            25-34 47.55%, 
            35-44 20.29%, 
            45-54 11.62%, 
            55-64 4.23%, 
            65+ 2.30%.
        Marital Status: 
            single - 61.05%, 
            married - 33.52%, 
            divorced - 1.96%, 
            widow/widower - 3.52%.
        Personal Values:
            Life Full of Excitement, Novelties, & Challenges - 22.10%,
            Freedom to Be Creative - 37.34%,
            Freedom to Determine Action - 46.38%,
            Enjoying Life’s Pleasures - 48.98%,
            Being in Charge and Directing People - 1.65%,
            Acquiring Wealth and Influence - 12.51%,
            Show Abilities and Be Admired - 5.91%,
            Maintaining a Good Public Image - 3.93%,
            Safety in Community and Nation - 12.64%,
            Safety in Oneself and Family - 28.00%,
            Avoiding Upsetting or Harming People - 31.03%,
            Obeying Laws and Fulfilling Obligations - 2.49%,
            Maintaining Traditions - 5.51%,
            Everyone Treated Equally - 35.29%,
            Caring for Nature - 17.18%,
            Being Reliable and Trustworthy - 12.91%,
            Being Humble - 23.92%,
            Acceptance of Those Who Are Different - 27.72%,
            Caring for Family/Friends - 16.93%.
        Hours Playing Video Games Per Week:
            5-10 Hours - 26.05%,
            20-40 Hours - 24.11%,
            10-20 Hours - 18.28%,
            2-5 Hours - 10.31%,
            0-1 Hour - 9.14%.
        Watch Others Play Video Games Online - 69.55%.
        Look for in Video Games:
            Immersion - 38.25%,
            Exploration - 30.08%,
            Achievement - 9.46%,
            Creativity - 7.43%,
            Community - 2.35%.
        Attributes Most Looked for in Video Games:
            To Feel Like a Kid - 41.91%,
            To Feel Powerful - 26.95%,
            To Feel a Sense of Nostalgia - 48.52%,
            To Engage With Characters You Love - 49.14%,
            To Feel Like You Can Do Anything - 36.25%.
        Video Game Genres:
            Role-Playing (Rpg) - 40.48%,
            Platform (e.g., Super Mario) - 19.54%,
            Open World (e.g., No Man’s Sky) - 20.96%,
            Japanese Role-Playing (Jrpg) (e.g., Final Fantasy) - 16.68%, 
            Massively Multiplayer Online (Mmo) (e.g., World of Warcraft) - 23.65%,
            Adventure (e.g., Legend of Zelda) - 57.33%,
            Real-Time Strategy (e.g., Starcraft, Civilization) - 8.88%,
            Survival (e.g., Don’t Starve) - 8.69%,
            First-Person Shooter - 38.49%,
            Wrestling - 1.54%.
        Psychological Drivers:
            Proving Competence/Skills - 57.12%,
            Devotion to God/Faith - 8.17%,
            Creativity - 55.31%,
            Expressing Individuality - 64.73%,
            Living an Exciting Life - 35.56%,
            Optimistic Outlook - 14.38%
            Recognition From Peers - 34.83%,
            Respect From Others - 6.43%,
            Romantic Love - 37.94%,
            Sexual Relationships - 27.02%,
            Social/Professional Status - 11.58%,
            Trust From Others - 17.33%.
        Hobbies & Habits - Entertainment:
            Apparel Shopping - 20.20%,
            Art/Photography - 28.90%,
            Arts and Crafts - 23.07%,
            Bowling - 10.05%,
            Enjoying Museum/Performing Arts - 30.63%,
            Enjoying Music - 35.69%,
            Entertained/Hosted Friends and Family at Home - 32.05%,
            Following TV Show - 68.42%
            Going to Movies - 45.87%,
            Happy Hour - 14.53%,
            Reading Regularly - 34.33%,
            Watching Documentary TV/Film - 51.87%
            Went Boating - 3.35%
            Went to a Club or Bar - 18.77%
            Went to a Music Festival or Concert - 21.87%.
        Daily Routine:
            Value Routine and Schedules - 30.12%,
            Eat With Family 4x per Week - 48.87%,
            Physically Active Family - 21.50%,
            Family Time Best Part of Day - 41.49%,
            Value Work Beyond Income - 36.09%,
            Keep Work and Life Separate - 59.91%,
            Exercise 2x or More Weekly - 55.22%,
            Value Athletic Accomplishments - 32.59%,
            Participate in Teams/Classes - 15.82%,
            Prefer Making Own Meals - 24.74%,
            Aware of Family Health History - 16.83%,
            Buy Food Based on Nutrition - 19.62%,
            Limit Calories/Fats/Salt - 16.18%,
            Regular Coffee Drinker - 25.18%,
            Avoid Drinking Soda - 17.43%,
            Prayer Important Part of Day - 11.96%,
            Life Grounded in Religion - 12.96%.
        """
)

for chunk in generate.stream({"messages": [request]}):
    print(chunk.content, end="")
    agent_prompt += chunk.content

# %%
# Your evaluation should consider the following aspects:

#             Clarity and Specificity: Determine whether the prompt clearly and specifically outlines the objectives for the agent. Does it provide enough detail about the type of YouTube community it aims to simulate (e.g., gaming, education, lifestyle) and the key features of this community?

#             Engagement Metrics: Evaluate how well the prompt addresses the incorporation of engagement metrics like likes, comments, and shares. Consider whether it suggests mechanisms for simulating realistic user interactions that reflect those metrics.

#             Content Diversity: Assess the prompt's approach to ensuring content diversity within the simulated community. Does it suggest methods for generating a variety of video topics, styles, and perspectives?

#             Adaptation to Trends: Consider whether the prompt includes strategies for the agent to adapt to evolving trends and preferences within the YouTube community. Does it propose ways to analyze and incorporate trending topics, hashtags, or popular formats?

#             Ethical Considerations: Reflect on whether the prompt addresses potential ethical concerns, such as the prevention of harmful content, respect for privacy, and promotion of positive interactions among simulated users.

# %%
You are a specialist in evaluating prompts designed for LLM-based community simulation agents. 
Analyze the following prompt for its effectiveness in representing the core values of openness to change, self-enhancement, conservation, and self-transcendence, as well as its ability to attract a diverse YouTube community.

Prompt: [Insert the LLM-generated prompt here]

Provide your analysis, identifying any strengths, weaknesses, and potential areas for improvement.

# %%
reflection_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
                You are a specialist in evaluating prompts designed for LLM-based community simulation agents. 
                Analyze the following prompt for its effectiveness in representing the core values of openness to change, self-enhancement, conservation, and self-transcendence, as well as its ability to attract a diverse YouTube community.

                Provide your analysis, identifying any strengths, weaknesses, and potential areas for improvement. 
            """
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
reflect = reflection_prompt | llm

# %%
reflection = ""
for chunk in reflect.stream({"messages": [request, HumanMessage(content=agent_prompt)]}):
    print(chunk.content, end="")
    reflection += chunk.content

# %%
for chunk in generate.stream(
    {"messages": [request, AIMessage(content=agent_prompt), HumanMessage(content=reflection)]}
):
    print(chunk.content, end="")

# %%
from typing import List, Sequence

from langgraph.graph import END, MessageGraph


async def generation_node(state: Sequence[BaseMessage]):
    return await generate.ainvoke({"messages": state})


async def reflection_node(messages: Sequence[BaseMessage]) -> List[BaseMessage]:
    # Other messages we need to adjust
    cls_map = {"ai": HumanMessage, "human": AIMessage}
    # First message is the original user request. We hold it the same for all nodes
    translated = [messages[0]] + [
        cls_map[msg.type](content=msg.content) for msg in messages[1:]
    ]
    res = await reflect.ainvoke({"messages": translated})
    # We treat the output of this as human feedback for the generator
    return HumanMessage(content=res.content)


builder = MessageGraph()
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.set_entry_point("generate")


def should_continue(state: List[BaseMessage]):
    if len(state) > 10:
        # End after 3 iterations
        return END
    return "reflect"


builder.add_conditional_edges("generate", should_continue)
builder.add_edge("reflect", "generate")
graph = builder.compile()

# %%
async for event in graph.astream(
    [
        HumanMessage(
    content= """
        Top Interests:
            Disney Lifestyle & Content
            Indie Gaming 
            Cosplay Content & 
            Fabrication 
            Gaming & Tech News 
            Disney Parks & Travel 
            Fan Art 
            Comic Illustrations 
            Fantasy TV 
            Horror Fandoms 
            Personal Development 
            LEGOs 
            Toy Photography.
        Gender: 
            79.68% Male,
        Household Income: 
            <$25k - 12.21%, 
            $25-50k - 18.45%, 
            $50 - 75k - 11.25%, 
            $100 - 150K - 19.03%, 
            >$150 - 13.45%.
        Age: 
            18-24 14.05%, 
            25-34 47.55%, 
            35-44 20.29%, 
            45-54 11.62%, 
            55-64 4.23%, 
            65+ 2.30%.
        Marital Status: 
            single - 61.05%, 
            married - 33.52%, 
            divorced - 1.96%, 
            widow/widower - 3.52%.
        Personal Values:
            Life Full of Excitement, Novelties, & Challenges - 22.10%,
            Freedom to Be Creative - 37.34%,
            Freedom to Determine Action - 46.38%,
            Enjoying Life’s Pleasures - 48.98%,
            Being in Charge and Directing People - 1.65%,
            Acquiring Wealth and Influence - 12.51%,
            Show Abilities and Be Admired - 5.91%,
            Maintaining a Good Public Image - 3.93%,
            Safety in Community and Nation - 12.64%,
            Safety in Oneself and Family - 28.00%,
            Avoiding Upsetting or Harming People - 31.03%,
            Obeying Laws and Fulfilling Obligations - 2.49%,
            Maintaining Traditions - 5.51%,
            Everyone Treated Equally - 35.29%,
            Caring for Nature - 17.18%,
            Being Reliable and Trustworthy - 12.91%,
            Being Humble - 23.92%,
            Acceptance of Those Who Are Different - 27.72%,
            Caring for Family/Friends - 16.93%.
        Hours Playing Video Games Per Week:
            5-10 Hours - 26.05%,
            20-40 Hours - 24.11%,
            10-20 Hours - 18.28%,
            2-5 Hours - 10.31%,
            0-1 Hour - 9.14%.
        Watch Others Play Video Games Online - 69.55%.
        Look for in Video Games:
            Immersion - 38.25%,
            Exploration - 30.08%,
            Achievement - 9.46%,
            Creativity - 7.43%,
            Community - 2.35%.
        Attributes Most Looked for in Video Games:
            To Feel Like a Kid - 41.91%,
            To Feel Powerful - 26.95%,
            To Feel a Sense of Nostalgia - 48.52%,
            To Engage With Characters You Love - 49.14%,
            To Feel Like You Can Do Anything - 36.25%.
        Video Game Genres:
            Role-Playing (Rpg) - 40.48%,
            Platform (e.g., Super Mario) - 19.54%,
            Open World (e.g., No Man’s Sky) - 20.96%,
            Japanese Role-Playing (Jrpg) (e.g., Final Fantasy) - 16.68%, 
            Massively Multiplayer Online (Mmo) (e.g., World of Warcraft) - 23.65%,
            Adventure (e.g., Legend of Zelda) - 57.33%,
            Real-Time Strategy (e.g., Starcraft, Civilization) - 8.88%,
            Survival (e.g., Don’t Starve) - 8.69%,
            First-Person Shooter - 38.49%,
            Wrestling - 1.54%.
        Psychological Drivers:
            Proving Competence/Skills - 57.12%,
            Devotion to God/Faith - 8.17%,
            Creativity - 55.31%,
            Expressing Individuality - 64.73%,
            Living an Exciting Life - 35.56%,
            Optimistic Outlook - 14.38%
            Recognition From Peers - 34.83%,
            Respect From Others - 6.43%,
            Romantic Love - 37.94%,
            Sexual Relationships - 27.02%,
            Social/Professional Status - 11.58%,
            Trust From Others - 17.33%.
        Hobbies & Habits - Entertainment:
            Apparel Shopping - 20.20%,
            Art/Photography - 28.90%,
            Arts and Crafts - 23.07%,
            Bowling - 10.05%,
            Enjoying Museum/Performing Arts - 30.63%,
            Enjoying Music - 35.69%,
            Entertained/Hosted Friends and Family at Home - 32.05%,
            Following TV Show - 68.42%
            Going to Movies - 45.87%,
            Happy Hour - 14.53%,
            Reading Regularly - 34.33%,
            Watching Documentary TV/Film - 51.87%
            Went Boating - 3.35%
            Went to a Club or Bar - 18.77%
            Went to a Music Festival or Concert - 21.87%.
        Daily Routine:
            Value Routine and Schedules - 30.12%,
            Eat With Family 4x per Week - 48.87%,
            Physically Active Family - 21.50%,
            Family Time Best Part of Day - 41.49%,
            Value Work Beyond Income - 36.09%,
            Keep Work and Life Separate - 59.91%,
            Exercise 2x or More Weekly - 55.22%,
            Value Athletic Accomplishments - 32.59%,
            Participate in Teams/Classes - 15.82%,
            Prefer Making Own Meals - 24.74%,
            Aware of Family Health History - 16.83%,
            Buy Food Based on Nutrition - 19.62%,
            Limit Calories/Fats/Salt - 16.18%,
            Regular Coffee Drinker - 25.18%,
            Avoid Drinking Soda - 17.43%,
            Prayer Important Part of Day - 11.96%,
            Life Grounded in Religion - 12.96%.
        """
        )
    ],
):
    print(event)
    print("---")

# %%
ChatPromptTemplate.from_messages(event[END]).pretty_print()
